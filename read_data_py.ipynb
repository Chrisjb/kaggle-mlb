# %% [markdown]
# # Read in train data from feather files
# Need to run *read_data_r.ipynb* first to generate feather files..

# %%
import pandas as pd

# %%
train_awards = pd.read_feather('raw_data/train_awards.feather')
train_events= pd.read_feather('raw_data/train_events.feather')
train_games = pd.read_feather('raw_data/train_games.feather')
train_engagement = pd.read_feather('raw_data/train_nextDayPlayerEngagement.feather')
train_player_boxscores = pd.read_feather('raw_data/train_playerBoxScores.feather')
train_player_followers = pd.read_feather('raw_data/train_playerTwitterFollowers.feather')
train_rosters = pd.read_feather('raw_data/train_rosters.feather')
train_standings = pd.read_feather('raw_data/train_standings.feather')
train_team_boxscores = pd.read_feather('raw_data/train_playerBoxScores.feather')
train_team_followers = pd.read_feather('raw_data/train_teamTwitterFollowers.feather')
train_transactions = pd.read_feather('raw_data/train_transactions.feather')

# %% [markdown]
# Two files contain awards. Looks like the training set contains current awards while *awards.csv* is historic awards

# %%
train_awards
# Out:
#         awardId                         awardName   awardDate  awardSeason  \
# 0       VWLCPOY   VWL Comeback Player of the Year  2018-01-15         2017
# 1        VWLPOY           VWL Pitcher of the Year  2018-01-15         2017
# 2        VWLMOY           VWL Manager of the Year  2018-01-15         2017
# 3       VWLRLOY          VWL Reliever of the Year  2018-01-15         2017
# 4       VWLOPOY  VWL Offensive Player of the Year  2018-01-15         2017
# ...         ...                               ...         ...          ...
# 5910      NLPOM            NL Player of the Month  2021-04-30         2021
# 5911  ALRRELMON          AL Reliever of the Month  2021-04-30         2021
# 5912      ALPOM            AL Player of the Month  2021-04-30         2021
# 5913      ALROM            AL Rookie of the Month  2021-04-30         2021
# 5914    ALPITOM           AL Pitcher of the Month  2021-04-30         2021
#
#       playerId         playerName  awardPlayerTeamId
# ...

# %%
awards = pd.read_csv('raw_data/awards.csv')
awards
# Out:
#         awardDate  awardSeason      awardId                       awardName  \
# 0      2017-12-21         2017  WARRENSPAHN              Warren Spahn Award
# 1      2017-12-20         2017    MILBORGAS  MiLB.com Organization All-Star
# 2      2017-12-20         2017    MILBORGAS  MiLB.com Organization All-Star
# 3      2017-12-20         2017    MILBORGAS  MiLB.com Organization All-Star
# 4      2017-12-20         2017    MILBORGAS  MiLB.com Organization All-Star
# ...           ...          ...          ...                             ...
# 11251  2000-08-27         2000        NLPOW           NL Player of the Week
# 11252  2000-07-09         2000      FUTURES          Futures Game Selection
# 11253  1998-09-01         1998       TLPSAS        TEX Post-Season All-Star
# 11254  1998-07-07         1998         ALAS                     AL All-Star
# 11255  1998-06-21         1998        ALPOW           AL Player of the Week
#
#        playerId       playerName  awardPlayerTeamId
# ...
